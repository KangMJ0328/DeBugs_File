# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
filepah = '/content/drive/MyDrive/프로젝트/노래 csv파일/SongChorus.csv'
df = pd.read_csv(filepah)
# Unnamde: 0 삭제
df=df.drop('Unnamed: 0',axis=1)
# 공백 행 삭제
# df = df[df.가사 != '[]']
df.iloc[:,[0,1,2]]
# Out:
#                         제목  ...                                                 가사
# 0                   태지 보이스  ...  [(" 'Taiji Boys 우리의 마음이'",), (" 'Taiji Boys 언제...
# 1               시대유감(時代遺憾)  ...  [(" '모든 삶을 포기하는 소리를'",), (" '일이 벌어질것 같네'",), (...
# 2                 수시아(誰是我)  ...                                                 []
# 3      이 밤이 깊어 가지만 (Remix)  ...  [(" '지금 전화를 걸어'",), (" '이밤이 깊어가지만'",), (" '언제까...
# 4               Free Style  ...  [(" '나의 그 생각들엔'",), (" '내 맘을 자극하는 바람'",), (" '...
# ...                    ...  ...                                                ...
# 16915    사계 (Four Seasons)  ...  [(' 그리고 또 떠나"',), ('" 온 세상이던 널 보낼래 "',), ('" 내...
# 16916                  찐이야  ...                                                 []
# 16917                    비  ...  [('" 그런널 왜 난 보냈을까"',), ('" 우리 걷던 이길위에"',), ('"...
# 16918         너에게 난, 나에게 넌  ...  [('" 한편의 아름다운 추억이 되고"',), ('" 소중했던 우리 푸르던 날을 기...
# ...

# %%
text1=df['가사'][0]
text1
text2 = df['가사'][1]

# %%
df_split_5 = df.가사[5].split()
df_split_5
df_split_5[0]
# Out:
# '[("'

# %%
df_split_5.remove(df_split_5[0])
df_split_5
# Out:
# ['\'\'",),', '("', "'오", '그대여', '가지', '마세요나를', '정말', '떠나가나요\'",)]']

# %%
# !pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 448 kB 39.6 MB/s
# ...
#      |████████████████████████████████| 86 kB 6.5 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
from konlpy.tag import Komoran
komoran = Komoran(userdic='/tmp/dic.txt')
komoran.nouns(text2)
# komoran.nouns(text2)
# Out:
# ['삶', '포기', '소리', '일', '것', '입술', '정직', '사람', '시대', '이세상', '오늘', '아우성', '수']

# %%
text2
# Out:
# '[(" \'모든 삶을 포기하는 소리를\'",), (" \'일이 벌어질것 같네\'",), (" \'검게 물든 입술\'",), (" \'정직한 사람들의 시대는 갔어\'",), (" \'이세상이 모두 미쳐버릴\'",), (" \'왜 기다려왔잖아\'",), (" \'오늘은 아우성을 들을 수 있어\'",)]'

# %%
from konlpy.tag import Komoran 
from numpy import dot 
from numpy.linalg import norm 
import numpy as np 
# 코사인 유사도를 구하는 함수 
def cos_sim(a, b): 
  return dot(a, b)/(norm(a)*norm(b)) 
# 기준이 되는 키워드와 벡터 키워드 리스트를 받아서 키워드별 빈도를 구하는 함수 
def make_matrix(feats, list_data): 
  freq_list = [] 
  for feat in feats: 
    freq = 0 
    for word in list_data: 
      if feat == word: 
          freq += 1 
    freq_list.append(freq) 
  return freq_list 
v1=komoran.nouns(text1)
v2=komoran.nouns(text2)
v3=Komoran.nouns()
# 단어들을 중복제거를 위해, set에 데이터를 쌓는다 
v4 = v1 + v2 
feats = set(v4) 
v1_arr = np.array(make_matrix(feats, v1)) 
v2_arr = np.array(make_matrix(feats, v2)) 
v3_arr = np.array(make_matrix(featsm v3))
cs1 = cos_sim(v1_arr, v2_arr) 
cs2 = cos_sim(v1_arr, v3_arr)
 

print('v1 <-> v2 = ', cs1)
# Out:
# v1 <-> v2 =  0.15819461514694902
