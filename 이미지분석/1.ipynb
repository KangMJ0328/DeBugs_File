# %%
import pandas as pd
filepah = '/content/drive/MyDrive/Project/노래 csv파일/After_Data_Pretreatment_Processing(13486).csv'
df_song = pd.read_csv(filepah)
df_song
# Out:
#        Unnamed: 0  ... emotion
# 0               0  ...      중립
# 1               1  ...      분노
# 2               2  ...      중립
# 3               3  ...      놀람
# 4               4  ...      분노
# ...           ...  ...     ...
# 13481       13481  ...      중립
# 13482       13482  ...      분노
# 13483       13483  ...      행복
# 13484       13484  ...      행복
# 13485       13485  ...      슬픔
#
# [13486 rows x 5 columns]

# %%
df_song['emotion'].unique()
# Out:
# array(['중립', '분노', '놀람', '행복', '공포', '슬픔', '혐오'], dtype=object)

# %%
df_song.columns[1]
# Out:
# 'title'

# %%
random.choice(df_song[df_song['emotion']=='중립'].index)
# Out:
# 5169

# %%
df_song[df_song['emotion']=='중립'].index
# Out:
# Int64Index([    0,     2,     7,    11,    19,    22,    23,    24,    25,
#                27,
#             ...
#             13426, 13428, 13451, 13453, 13455, 13463, 13475, 13478, 13480,
#             13481],
#            dtype='int64', length=1517)

# %%
import random
df_song[['title','artist']].iloc[random.choice(df_song[df_song['emotion']=='중립'].index)]
# Out:
# title     Into the Light
# artist               솔리드
# Name: 86, dtype: object

# %%
from PIL import Image
import os, glob, numpy as np
from keras.models import load_model
# 비교해볼 이미지 파일 넣는 곳  
caltech_dir = "/content/drive/MyDrive/Project/이미지분석/이미지 분석코드,모델/test"
# 불러올 이미지 크기
image_w = 128
image_h = 128
pixels = image_h * image_w * 3

X = []
filenames = []
files = glob.glob(caltech_dir+"/*.*")
for i, f in enumerate(files):
    img = Image.open(f)
    img = img.convert("RGB")
    img = img.resize((image_w, image_h))
    data = np.asarray(img)
    filenames.append(f)
    X.append(data)

X = np.array(X)

# %%
print_text1=[]

# %%
import random
# 기존에 만든 모델 불러오기 
categories=['거실','공항내부','빵집','술집','식당','장난감가게','주방','지하철','창고','침실']
model = load_model('/content/drive/MyDrive/Project/이미지분석/이미지 분석코드,모델/model/multi_img_classification.model')

prediction = model.predict(X)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
cnt = 0
print_text1=[]
# print_text2=[]
# print_text3=[]
# print_text4=[]
# print_text5=[]
# print_text6=[]
# print_text7=[]
# print_text8=[]
# print_text9=[]
# print_text10=[]
#이 비교는 그냥 파일들이 있으면 해당 파일과 비교. 카테고리와 함께 비교해서 진행하는 것은 _4 파일.
for i in prediction:
    pre_ans = i.argmax()  # 예측 레이블
#     print(i)
#     print(pre_ans)
    pre_ans_str = ''
    pre_ans_str = categories[pre_ans]
    if pre_ans_str=='장난감가게':
      print_text1.append(df_song[['title','artist']].iloc[random.choice(df_song[df_song['emotion']=='중립'].index)])
    if pre_ans_str=='거실':
      print_text1.append(df_song[['title','artist']].iloc[random.choice(df_song[df_song['emotion']=='행복'].index)])
    if pre_ans_str=='공항내부':
      print_text1.append(df_song[['title','artist']].iloc[random.choice(df_song[df_song['emotion']=='분노'].index)])
    if pre_ans_str=='빵집':
      print_text1.append(df_song[['title','artist']].iloc[random.choice(df_song[df_song['emotion']=='슬픔'].index)])
    if pre_ans_str=='술집':
      print_text1.append(df_song[['title','artist']].iloc[random.choice(df_song[df_song['emotion']=='행복'].index)])
    if pre_ans_str=='식당':
      print_text1.append(df_song[['title','artist']].iloc[random.choice(df_song[df_song['emotion']=='행복'].index)])
    if pre_ans_str=='주방':
      print_text1.append(df_song[['title','artist']].iloc[random.choice(df_song[df_song['emotion']=='놀람'].index)])
    if pre_ans_str=='지하철':
      print_text1.append(df_song[['title','artist']].iloc[random.choice(df_song[df_song['emotion']=='혐오'].index)])
    if pre_ans_str=='창고':
      print_text1.append(df_song[['title','artist']].iloc[random.choice(df_song[df_song['emotion']=='공포'].index)])
    if pre_ans_str=='침실':
      print_text1.append(df_song[['title','artist']].iloc[random.choice(df_song[df_song['emotion']=='행복'].index)])                              
    # print("해당 "+filenames[cnt].split("/")[-1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
#     print("입력해주신 이미지는 "+pre_ans_str+"로 추정됩니다.")
    print("==================================================================================")
   
    cnt += 1
#     print(i.argmax()) #얘가 레이블 [1. 0. 0.] 이런식으로 되어 있는 것을 숫자로 바꿔주는 것.
    # 즉 얘랑, 나중에 카테고리 데이터 불러와서 카테고리랑 비교를 해서 같으면 맞는거고, 아니면 틀린거로 취급하면 된다.
    # 이걸 한 것은 _4.py에.

# %%
print_text1
# Out:
# [title     Radio Star
#  artist       더블에스오공일
#  Name: 5117, dtype: object, title     Chronos Soul
#  artist             씨스타
#  Name: 8174, dtype: object]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
