# %%
install -c -forge spleeter
# Out:
#   File "<ipython-input-3-b9ba3eea4c4a>", line 1
#     install -c -forge spleeter
#                              ^
# SyntaxError: invalid syntax

# %%
pip install spleeter
