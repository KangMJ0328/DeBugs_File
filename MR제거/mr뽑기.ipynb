# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
pip install spleeter

# %%
from IPython.display import Audio

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import cv2

path = '/content/drive/MyDrive/Project/MR제거/솔개'

path_dir = path
file_list = os.listdir(path_dir)

# %%
file_list

# %%
song_list = []
for i in range(0, len(file_list)):
    if file_list[i][-4:] == ".mp3":
        song_list.append(file_list[i])

# %%
song_list
# Out:
# ['冯提莫《爱的魔法》.3gpp.mp3',
#  '冯提莫《勾指起誓》.3gpp.mp3',
#  '王伟丞 - 暖暖 (Cover 梁静茹)【動態歌詞Lyrics Video】.3gpp.mp3',
#  '王七七梨子 - 談戀愛【高音質】.3gpp.mp3',
#  '王七七《月夜》【水怪 Water Monster OST電影插曲】官方高畫質 Official HD MV.3gpp.mp3',
#  '王七七 - 來到我的城市  ✤那就來到我的城市異地真的不好過✤【高音質動態歌詞Lyrics】【Chinese Music】.3gpp.mp3',
#  '杨胖雨 - 这就是爱吗【動態歌詞Lyrics Video】.3gpp.mp3',
#  '我一点都不想你-BigYear大年(너 하나도 안 보고 싶어-BigYear大年) 가사 해석.3gpp.mp3',
#  '张远 - 嘉宾『感谢你特别邀请来见证你的爱情我时刻提醒自己别逃避』【 完整版 】.3gpp.mp3',
#  '司南 - 冬眠【動態歌詞Lyrics Video】.3gpp.mp3',
#  '十豆彡 - 这就是爱吗【動態歌詞Lyrics Video】.3gpp.mp3',
#  '劉增瞳 - 你從不知道【動態歌詞】.3gpp.mp3',
#  '冯提莫翻唱周深《大鱼》.3gpp.mp3',
#  '귀염귀염열매 능력자 펑티모가 부르는 《고백풍선  告白气球》 주걸륜의 스윗한 노래 COVER by Fengtimo 冯提莫.3gpp.mp3',
#  '귀여운 사랑 노래 《사랑은 바로 너야 (爱的就是你  Love is you) 》 COVER by Fengtimo.3gpp.mp3',
#  '강산도 앞길을 막지 못하리라 (山止川行 shān zhĭ chuān xíng) - 부차이 (不才)  가사해석 번역 병음 발음 [중국노래  추천].3gpp.mp3',
# ...

# %%
filename_list = []
filename_f_list = []
for i in range(0, len(song_list)):
  filename = "'/content/drive/MyDrive/Project/MR제거/솔개/" + song_list[i] + "'"
  filename_f = song_list[i]
  filename_list.append(filename)
  filename_f_list.append(filename_f)

# %%
filename_list
# Out:
# ["'/content/drive/MyDrive/Project/MR제거/솔개/冯提莫《爱的魔法》.3gpp.mp3'",
#  "'/content/drive/MyDrive/Project/MR제거/솔개/冯提莫《勾指起誓》.3gpp.mp3'",
#  "'/content/drive/MyDrive/Project/MR제거/솔개/王伟丞 - 暖暖 (Cover 梁静茹)【動態歌詞Lyrics Video】.3gpp.mp3'",
#  "'/content/drive/MyDrive/Project/MR제거/솔개/王七七梨子 - 談戀愛【高音質】.3gpp.mp3'",
#  "'/content/drive/MyDrive/Project/MR제거/솔개/王七七《月夜》【水怪 Water Monster OST電影插曲】官方高畫質 Official HD MV.3gpp.mp3'",
#  "'/content/drive/MyDrive/Project/MR제거/솔개/王七七 - 來到我的城市  ✤那就來到我的城市異地真的不好過✤【高音質動態歌詞Lyrics】【Chinese Music】.3gpp.mp3'",
#  "'/content/drive/MyDrive/Project/MR제거/솔개/杨胖雨 - 这就是爱吗【動態歌詞Lyrics Video】.3gpp.mp3'",
#  "'/content/drive/MyDrive/Project/MR제거/솔개/我一点都不想你-BigYear大年(너 하나도 안 보고 싶어-BigYear大年) 가사 해석.3gpp.mp3'",
#  "'/content/drive/MyDrive/Project/MR제거/솔개/张远 - 嘉宾『感谢你特别邀请来见证你的爱情我时刻提醒自己别逃避』【 完整版 】.3gpp.mp3'",
#  "'/content/drive/MyDrive/Project/MR제거/솔개/司南 - 冬眠【動態歌詞Lyrics Video】.3gpp.mp3'",
# ...

# %%
filename_list[2]
# Out:
# "'/content/drive/MyDrive/Project/MR제거/솔개/王伟丞 - 暖暖 (Cover 梁静茹)【動態歌詞Lyrics Video】.3gpp.mp3'"

# %%
import glob

# %%
# !spleeter separate -o drive/MyDrive/Project/MR제거/솔개/mr -p spleeter:2stems-16kHz glob('/content/drive/MyDrive/Project/MR제거/솔개/*.mp3')
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `spleeter separate -o drive/MyDrive/Project/MR제거/솔개/mr -p spleeter:2stems-16kHz glob('/content/drive/MyDrive/Project/MR제거/솔개/*.mp3')'

# %%
import os
import subprocess


for filename in filename_list :
  batcmd = 'spleeter separate -o drive/MyDrive/Project/MR제거/솔개/mr -p spleeter:2stems-16kHz ' + filename
  result = subprocess.check_output(batcmd, shell = True)
  print(result.decode('utf-8'))
  #call('!spleeter separate -o /drive/MyDrive/Project/MR제거/솔개/mr -p spleeter:2stems-16khz ' + filename_list[i])

# %%
굳 똘똘이형
